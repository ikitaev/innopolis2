# %% [markdown]
# ## Подготовка

# %%
# импортируем нужные библиотеки
import pandas as pd
import numpy as np

from ast import literal_eval

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder

from lazypredict.Supervised import LazyClassifier
from xgboost import XGBClassifier 
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from catboost import CatBoostClassifier

# %%
# версия решения
version = 20

# %%
# пишем класс, вычисляющий групповые статистики
class MeanGrouper():
    """
    Класс, вычисляющий групповые статистики.
    
    Параметры
    ----------    
    group_cols: list
        Список группирующих столбцов.
    agg_col: str
        Агрегируемый столбец.
    agg_func: str
        Агрегирующая функция.
   
    Возвращает
    -------
    X : pandas.DataFrame
        Датафрейм с групповыми статистиками.
    """
    def __init__(self, group_cols, agg_col, agg_func='mean'):
        
        if agg_func not in ['mean', 'median', 'min', 'max', 'std', 'skew']:
            raise ValueError(
                f"Неизвестная агрегирующая функция {agg_func}")
        
        if type(agg_func) != str:
            raise ValueError("Агрегирующая функция должна" + 
                             "иметь строковое значение")
            
        # превращаем столбец в список
        if type(group_cols) != list:
            group_cols = [group_cols]
            
        self.group_cols = group_cols
        self.agg_col = agg_col
        self.agg_func = agg_func
    
    def fit(self, X, y=None):
        
        # проверка наличия пропусков в группирующих столбцах
        if pd.isnull(X[self.group_cols]).any(axis=None) == True:
             raise ValueError(f"Есть пропуски в группирующих столбцах")
        
        # задаем имя
        self.name = '{0}_by_{1}_{2}'.format(
            self.agg_col, self.group_cols, self.agg_func)
        # получаем средние по каждой комбинации категорий
        # признаков в списке
        self.grp = X.groupby(self.group_cols)[[self.agg_col]].agg(
            self.agg_func)
        
        return self 
    
    def transform(self, X, y=None):
        
        # присваиваем имя
        self.grp.columns = [self.name]
        # записываем результаты  
        X = pd.merge(X, self.grp, 
                     left_on=self.group_cols, 
                     right_index=True, how='left')
          
        # пропуски кодируем отдельным значением -1
        X = X.fillna(-1)
        
        return X

# %%
# парсер координат
def coord_parser(row):
    if row['type'] == 'Polygon':
        return row['coordinates'][0][0]
    if row['type'] == 'MultiPolygon':
        return row['coordinates'][0][0][0]
    return row['coordinates'][0]['coordinates'][0]

# %%
# загрузка тренировочного датасета
df = pd.read_csv('../../data/train_dataset_train.csv')

# %%
# функция препроцессинга данных
def preprocessing(df, new_df=False):
    lst = df.filter(regex='nd_mean').columns.tolist()
    lst2 = df.filter(regex='nd_mean').columns.str.lstrip('nd_mean').tolist()
    dictionary = dict(zip(lst, lst2))
    df.rename(columns=dictionary, inplace=True)
    df[['type', 'coordinates']] = pd.DataFrame(
        df['.geo']
        .apply(lambda x: literal_eval(x).values())
        .tolist()
        )
    df[['coord1', 'coord2']] = pd.DataFrame(
        df
        .apply(coord_parser, axis=1)
        .tolist()
        )
    if new_df:
        ident = df['id']       
        X = df.drop(['id', '.geo', 'type', 'coordinates'], axis=1)
    else:
        X = df.drop(['id', '.geo', 'crop', 'type', 'coordinates'], axis=1)
        y = df['crop']
    X = X.sort_index(axis=1)

    X['mean'] = X[X.filter(regex='2021').columns].mean(axis=1)
    X['std'] = X[X.filter(regex='2021').columns].std(axis=1)
    X['diff'] = (X[X.filter(regex='2021').columns].max(axis=1) -
                 X[X.filter(regex='2021').columns].min(axis=1))

    if new_df:
        return X, ident
    else:
        return X, y

# %%
# препроцессинг тренировочного датасета
X, y = preprocessing(df)

# %%
# загружаем регионы РФ согласно координатам наблюдений
df_regions = pd.read_csv('../../data/regions_hist.csv')

# %%
# присоединяем регионы к датасету
X = pd.concat([X, df_regions], axis=1)

# %% [markdown]
# ## Выбор моделей

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=42,
                                                    stratify=y)

# %%
# выберем модели для ансамблирования
lc = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
lazy_models, predictions = lc.fit(X_train, X_test, y_train, y_test)
print(lazy_models)
# Out:
# 100%|██████████| 29/29 [00:19<00:00,  1.48it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.96               0.96    None      0.96
# LGBMClassifier                     0.96               0.96    None      0.96
# ExtraTreesClassifier               0.96               0.96    None      0.96
# RandomForestClassifier             0.95               0.95    None      0.95
# SVC                                0.95               0.95    None      0.95
# LinearSVC                          0.94               0.95    None      0.95
# CalibratedClassifierCV             0.94               0.94    None      0.94
# QuadraticDiscriminantAnalysis      0.94               0.94    None      0.94
# LogisticRegression                 0.94               0.94    None      0.94
# RidgeClassifier                    0.94               0.94    None      0.94
# RidgeClassifierCV                  0.94               0.94    None      0.94
# LinearDiscriminantAnalysis         0.93               0.93    None      0.93
# PassiveAggressiveClassifier        0.93               0.93    None      0.93
# GaussianNB                         0.93               0.93    None      0.93
# Perceptron                         0.93               0.93    None      0.93
# NuSVC                              0.92               0.93    None      0.93
# SGDClassifier                      0.92               0.92    None      0.92
# BaggingClassifier                  0.92               0.92    None      0.92
# KNeighborsClassifier               0.92               0.92    None      0.92
# DecisionTreeClassifier             0.88               0.88    None      0.88
# BernoulliNB                        0.82               0.82    None      0.82
# AdaBoostClassifier                 0.72               0.73    None      0.72
# ExtraTreeClassifier                0.71               0.71    None      0.71
# NearestCentroid                    0.71               0.71    None      0.71
# LabelSpreading                     0.42               0.42    None      0.45
# LabelPropagation                   0.42               0.42    None      0.45
# DummyClassifier                    0.15               0.14    None      0.04
#
#                                Time Taken
# Model
# XGBClassifier                        3.05
# LGBMClassifier                       3.26
# ExtraTreesClassifier                 0.65
# RandomForestClassifier               1.63
# SVC                                  0.53
# LinearSVC                            0.54
# CalibratedClassifierCV               1.94
# QuadraticDiscriminantAnalysis        0.08
# LogisticRegression                   0.25
# RidgeClassifier                      0.07
# RidgeClassifierCV                    0.08
# LinearDiscriminantAnalysis           0.26
# PassiveAggressiveClassifier          0.11
# GaussianNB                           0.06
# Perceptron                           0.10
# NuSVC                                1.28
# SGDClassifier                        0.20
# BaggingClassifier                    1.36
# KNeighborsClassifier                 0.10
# DecisionTreeClassifier               0.24
# BernoulliNB                          0.07
# AdaBoostClassifier                   1.59
# ExtraTreeClassifier                  0.05
# NearestCentroid                      0.05
# LabelSpreading                       1.07
# LabelPropagation                     0.90
# DummyClassifier                      0.04

# %% [markdown]
# ## Обучение

# %%
# генератор кортежей групповых статистик для пайплайна
list_of_mean_grouper = []
names = []
agg_funcs = ['mean', 'median', 'min', 'max', 'std', 'skew']
agg_cols = X.filter(regex='coord1').columns
group_cols = ['state']
for g in group_cols:
    for ac in agg_cols:
        for f in agg_funcs:
            a = MeanGrouper(
                g, 
                agg_col=ac, 
                agg_func=f)
            name = '+'.join([g,ac,f])
            names.append(name)
            result = (name, a)
            list_of_mean_grouper.append(result)

# %%
# лучшие параметры для случайного леса
best_params_rf = {
    "n_estimators": 772,
    "max_depth": 180,
    "min_samples_split": 4,
    "min_samples_leaf": 2,
}

# %%
# порядковое кодирование регионов
cat_pipe = Pipeline(
    [
        (
            'cat_encoder',
            OrdinalEncoder(
                handle_unknown='use_encoded_value',
                unknown_value=-1))
        ]
    )
cat_preprocessor = ColumnTransformer(
   [
    ('cat', cat_pipe, ['state'])
    ], remainder='passthrough'
   )

# %%
# формирование датасета для финального решения
new = pd.read_csv('../../data/test_dataset_test.csv')
X_new, ident = preprocessing(new, new_df=True)
df_regions_new = pd.read_csv('../../data/regions_new.csv')
X_new = pd.concat([X_new, df_regions_new], axis=1)

# %%
# модели для ансамбля
models = [
    CatBoostClassifier,
    RandomForestClassifier,
    XGBClassifier,
    LGBMClassifier,
    ExtraTreesClassifier
        ]

# %%
# генерируем экземпляры классов моделей обучения
model_instances = []
random_states = range(5, 30, 1)
for model in models:
    for r in random_states:
        model_instances.append(model().set_params(**{'random_state': r}))

# %%
# обучаем модели и ансамблируем решения
probas = []
for model in model_instances:
    if (
        (type(model) != 'lightgbm.sklearn.LGBMClassifier') or
        (type(model) != 'sklearn.ensemble._forest.RandomForestClassifier')):
        grouper = list_of_mean_grouper
    else:
        grouper = []

    clf = Pipeline(
        grouper +
        [
            ('cat_encoder', cat_preprocessor),
            ('scaler', StandardScaler()),
            ('rf', model)
            ])  

    print(clf.named_steps['rf'])  
    clf.fit(X, y)
    proba = clf.predict_proba(X_new)
    probas.append(proba)
    
mean_probas = np.mean(probas, axis=0)
pred = np.argmax(mean_probas, axis=1)

# формируем посылку
pd.DataFrame({'id': ident, 'crop': pred}).to_csv(
    f'../../data/submissions/subm_a{version}.csv', index=False)
# Out:
# <catboost.core.CatBoostClassifier object at 0x000001BD49D5A8B0>
# Learning rate set to 0.085744
# 0:	learn: 1.7199947	total: 332ms	remaining: 5m 31s
# 1:	learn: 1.5532884	total: 440ms	remaining: 3m 39s
# 2:	learn: 1.4173378	total: 538ms	remaining: 2m 58s
# 3:	learn: 1.3094447	total: 639ms	remaining: 2m 39s
# 4:	learn: 1.2254909	total: 736ms	remaining: 2m 26s
# 5:	learn: 1.1521629	total: 860ms	remaining: 2m 22s
# 6:	learn: 1.0769754	total: 975ms	remaining: 2m 18s
# 7:	learn: 1.0167415	total: 1.13s	remaining: 2m 19s
# 8:	learn: 0.9649809	total: 1.25s	remaining: 2m 17s
# 9:	learn: 0.9154959	total: 1.37s	remaining: 2m 15s
# 10:	learn: 0.8729837	total: 1.52s	remaining: 2m 16s
# 11:	learn: 0.8282794	total: 1.67s	remaining: 2m 17s
# 12:	learn: 0.7912463	total: 1.85s	remaining: 2m 20s
# 13:	learn: 0.7524827	total: 1.98s	remaining: 2m 19s
# 14:	learn: 0.7214053	total: 2.12s	remaining: 2m 18s
# 15:	learn: 0.6909199	total: 2.24s	remaining: 2m 17s
# 16:	learn: 0.6654293	total: 2.34s	remaining: 2m 15s
# 17:	learn: 0.6411250	total: 2.42s	remaining: 2m 12s
# 18:	learn: 0.6196447	total: 2.52s	remaining: 2m 10s
# 19:	learn: 0.5979510	total: 2.61s	remaining: 2m 8s
# 20:	learn: 0.5780189	total: 2.73s	remaining: 2m 7s
# 21:	learn: 0.5569784	total: 2.81s	remaining: 2m 4s
# 22:	learn: 0.5396786	total: 2.9s	remaining: 2m 3s
# 23:	learn: 0.5219852	total: 3s	remaining: 2m 1s
# 24:	learn: 0.5080040	total: 3.12s	remaining: 2m 1s
# 25:	learn: 0.4921600	total: 3.23s	remaining: 2m
# 26:	learn: 0.4782077	total: 3.34s	remaining: 2m
# 27:	learn: 0.4644314	total: 3.43s	remaining: 1m 59s
# 28:	learn: 0.4511426	total: 3.52s	remaining: 1m 57s
# 29:	learn: 0.4404607	total: 3.61s	remaining: 1m 56s
# 30:	learn: 0.4285758	total: 3.72s	remaining: 1m 56s
# 31:	learn: 0.4186308	total: 3.83s	remaining: 1m 55s
# 32:	learn: 0.4079751	total: 3.91s	remaining: 1m 54s
# 33:	learn: 0.3979612	total: 4s	remaining: 1m 53s
# 34:	learn: 0.3883400	total: 4.09s	remaining: 1m 52s
# 35:	learn: 0.3792026	total: 4.18s	remaining: 1m 52s
# 36:	learn: 0.3717658	total: 4.28s	remaining: 1m 51s
# 37:	learn: 0.3635318	total: 4.36s	remaining: 1m 50s
# 38:	learn: 0.3554169	total: 4.44s	remaining: 1m 49s
# 39:	learn: 0.3485385	total: 4.51s	remaining: 1m 48s
# 40:	learn: 0.3418456	total: 4.59s	remaining: 1m 47s
# 41:	learn: 0.3350693	total: 4.67s	remaining: 1m 46s
# 42:	learn: 0.3296690	total: 4.74s	remaining: 1m 45s
# 43:	learn: 0.3224437	total: 4.81s	remaining: 1m 44s
# 44:	learn: 0.3168772	total: 4.9s	remaining: 1m 43s
# 45:	learn: 0.3101216	total: 4.97s	remaining: 1m 43s
# 46:	learn: 0.3053406	total: 5.04s	remaining: 1m 42s
# 47:	learn: 0.3004110	total: 5.11s	remaining: 1m 41s
# 48:	learn: 0.2957690	total: 5.18s	remaining: 1m 40s
# 49:	learn: 0.2905746	total: 5.25s	remaining: 1m 39s
# 50:	learn: 0.2858178	total: 5.33s	remaining: 1m 39s
# 51:	learn: 0.2797641	total: 5.39s	remaining: 1m 38s
# 52:	learn: 0.2754374	total: 5.47s	remaining: 1m 37s
# 53:	learn: 0.2711984	total: 5.54s	remaining: 1m 36s
# 54:	learn: 0.2667090	total: 5.6s	remaining: 1m 36s
# 55:	learn: 0.2635991	total: 5.66s	remaining: 1m 35s
# 56:	learn: 0.2599713	total: 5.73s	remaining: 1m 34s
# 57:	learn: 0.2561844	total: 5.79s	remaining: 1m 34s
# 58:	learn: 0.2523412	total: 5.86s	remaining: 1m 33s
# 59:	learn: 0.2497846	total: 5.92s	remaining: 1m 32s
# 60:	learn: 0.2461516	total: 5.99s	remaining: 1m 32s
# 61:	learn: 0.2427266	total: 6.05s	remaining: 1m 31s
# 62:	learn: 0.2391805	total: 6.12s	remaining: 1m 31s
# 63:	learn: 0.2365230	total: 6.19s	remaining: 1m 30s
# 64:	learn: 0.2333564	total: 6.26s	remaining: 1m 30s
# 65:	learn: 0.2306027	total: 6.36s	remaining: 1m 30s
# 66:	learn: 0.2284431	total: 6.48s	remaining: 1m 30s
# 67:	learn: 0.2256100	total: 6.61s	remaining: 1m 30s
# 68:	learn: 0.2236761	total: 6.69s	remaining: 1m 30s
# 69:	learn: 0.2206941	total: 6.81s	remaining: 1m 30s
# 70:	learn: 0.2176457	total: 6.92s	remaining: 1m 30s
# 71:	learn: 0.2158081	total: 7.02s	remaining: 1m 30s
# 72:	learn: 0.2135502	total: 7.1s	remaining: 1m 30s
# 73:	learn: 0.2108488	total: 7.19s	remaining: 1m 29s
# 74:	learn: 0.2084410	total: 7.3s	remaining: 1m 30s
# 75:	learn: 0.2069284	total: 7.42s	remaining: 1m 30s
# 76:	learn: 0.2041976	total: 7.54s	remaining: 1m 30s
# 77:	learn: 0.2029199	total: 7.67s	remaining: 1m 30s
# 78:	learn: 0.2001422	total: 7.76s	remaining: 1m 30s
# 79:	learn: 0.1977272	total: 7.87s	remaining: 1m 30s
# 80:	learn: 0.1956978	total: 8s	remaining: 1m 30s
# 81:	learn: 0.1942480	total: 8.09s	remaining: 1m 30s
# 82:	learn: 0.1923950	total: 8.18s	remaining: 1m 30s
# 83:	learn: 0.1909747	total: 8.27s	remaining: 1m 30s
# 84:	learn: 0.1895960	total: 8.37s	remaining: 1m 30s
# 85:	learn: 0.1878471	total: 8.47s	remaining: 1m 30s
# 86:	learn: 0.1858483	total: 8.59s	remaining: 1m 30s
# 87:	learn: 0.1840831	total: 8.68s	remaining: 1m 29s
# 88:	learn: 0.1824155	total: 8.77s	remaining: 1m 29s
# 89:	learn: 0.1813552	total: 8.87s	remaining: 1m 29s
# 90:	learn: 0.1795468	total: 8.96s	remaining: 1m 29s
# 91:	learn: 0.1776396	total: 9.05s	remaining: 1m 29s
# 92:	learn: 0.1759938	total: 9.15s	remaining: 1m 29s
# 93:	learn: 0.1740389	total: 9.24s	remaining: 1m 29s
# 94:	learn: 0.1726128	total: 9.34s	remaining: 1m 28s
# 95:	learn: 0.1718311	total: 9.42s	remaining: 1m 28s
# 96:	learn: 0.1705607	total: 9.51s	remaining: 1m 28s
# 97:	learn: 0.1681192	total: 9.6s	remaining: 1m 28s
# 98:	learn: 0.1672088	total: 9.68s	remaining: 1m 28s
# 99:	learn: 0.1654398	total: 9.78s	remaining: 1m 27s
# 100:	learn: 0.1639979	total: 9.88s	remaining: 1m 27s
# 101:	learn: 0.1628769	total: 9.98s	remaining: 1m 27s
# 102:	learn: 0.1610839	total: 10.1s	remaining: 1m 27s
# 103:	learn: 0.1598811	total: 10.1s	remaining: 1m 27s
# 104:	learn: 0.1585732	total: 10.2s	remaining: 1m 27s
# 105:	learn: 0.1579747	total: 10.3s	remaining: 1m 27s
# 106:	learn: 0.1566135	total: 10.4s	remaining: 1m 26s
# 107:	learn: 0.1549158	total: 10.5s	remaining: 1m 26s
# 108:	learn: 0.1537089	total: 10.6s	remaining: 1m 26s
# 109:	learn: 0.1525200	total: 10.7s	remaining: 1m 26s
# 110:	learn: 0.1516894	total: 10.8s	remaining: 1m 26s
# 111:	learn: 0.1503850	total: 10.9s	remaining: 1m 26s
# 112:	learn: 0.1489798	total: 11s	remaining: 1m 26s
# 113:	learn: 0.1475258	total: 11.1s	remaining: 1m 26s
# 114:	learn: 0.1465429	total: 11.2s	remaining: 1m 26s
# 115:	learn: 0.1451991	total: 11.4s	remaining: 1m 26s
# 116:	learn: 0.1443030	total: 11.4s	remaining: 1m 26s
# 117:	learn: 0.1434658	total: 11.5s	remaining: 1m 26s
# 118:	learn: 0.1423621	total: 11.6s	remaining: 1m 26s
# 119:	learn: 0.1416081	total: 11.7s	remaining: 1m 25s
# 120:	learn: 0.1407921	total: 11.8s	remaining: 1m 25s
# 121:	learn: 0.1398218	total: 11.9s	remaining: 1m 25s
# 122:	learn: 0.1382191	total: 12s	remaining: 1m 25s
# 123:	learn: 0.1376861	total: 12.1s	remaining: 1m 25s
# 124:	learn: 0.1362528	total: 12.2s	remaining: 1m 25s
# 125:	learn: 0.1351660	total: 12.3s	remaining: 1m 25s
# 126:	learn: 0.1345445	total: 12.4s	remaining: 1m 25s
# 127:	learn: 0.1334048	total: 12.4s	remaining: 1m 24s
# 128:	learn: 0.1328110	total: 12.5s	remaining: 1m 24s
# 129:	learn: 0.1318465	total: 12.6s	remaining: 1m 24s
# 130:	learn: 0.1308399	total: 12.6s	remaining: 1m 23s
# 131:	learn: 0.1300750	total: 12.7s	remaining: 1m 23s
# 132:	learn: 0.1295530	total: 12.8s	remaining: 1m 23s
# 133:	learn: 0.1283645	total: 12.9s	remaining: 1m 23s
# 134:	learn: 0.1276205	total: 12.9s	remaining: 1m 22s
# 135:	learn: 0.1273389	total: 13s	remaining: 1m 22s
# 136:	learn: 0.1266214	total: 13.1s	remaining: 1m 22s
# 137:	learn: 0.1261882	total: 13.1s	remaining: 1m 22s
# 138:	learn: 0.1252564	total: 13.2s	remaining: 1m 21s
# 139:	learn: 0.1246086	total: 13.3s	remaining: 1m 21s
# 140:	learn: 0.1233351	total: 13.3s	remaining: 1m 21s
# 141:	learn: 0.1226257	total: 13.4s	remaining: 1m 21s
# 142:	learn: 0.1218967	total: 13.5s	remaining: 1m 20s
# 143:	learn: 0.1213120	total: 13.7s	remaining: 1m 21s
# 144:	learn: 0.1208573	total: 13.8s	remaining: 1m 21s
# 145:	learn: 0.1205860	total: 13.9s	remaining: 1m 21s
# 146:	learn: 0.1194206	total: 14s	remaining: 1m 21s
# 147:	learn: 0.1188482	total: 14.1s	remaining: 1m 21s
# 148:	learn: 0.1179870	total: 14.2s	remaining: 1m 21s
# 149:	learn: 0.1175668	total: 14.3s	remaining: 1m 20s
# 150:	learn: 0.1172117	total: 14.3s	remaining: 1m 20s
# 151:	learn: 0.1168298	total: 14.4s	remaining: 1m 20s
# 152:	learn: 0.1160212	total: 14.5s	remaining: 1m 20s
# 153:	learn: 0.1154354	total: 14.5s	remaining: 1m 19s
# 154:	learn: 0.1146744	total: 14.6s	remaining: 1m 19s
# 155:	learn: 0.1140364	total: 14.7s	remaining: 1m 19s
# 156:	learn: 0.1136540	total: 14.7s	remaining: 1m 19s
# 157:	learn: 0.1132667	total: 14.8s	remaining: 1m 18s
# 158:	learn: 0.1124623	total: 14.9s	remaining: 1m 18s
# 159:	learn: 0.1115945	total: 14.9s	remaining: 1m 18s
# 160:	learn: 0.1109769	total: 15s	remaining: 1m 18s
# 161:	learn: 0.1104071	total: 15.1s	remaining: 1m 17s
# 162:	learn: 0.1097310	total: 15.1s	remaining: 1m 17s
# 163:	learn: 0.1091274	total: 15.2s	remaining: 1m 17s
# 164:	learn: 0.1087044	total: 15.3s	remaining: 1m 17s
# 165:	learn: 0.1083263	total: 15.3s	remaining: 1m 16s
# 166:	learn: 0.1079764	total: 15.4s	remaining: 1m 16s
# 167:	learn: 0.1075291	total: 15.4s	remaining: 1m 16s
# 168:	learn: 0.1065560	total: 15.5s	remaining: 1m 16s
# 169:	learn: 0.1060486	total: 15.6s	remaining: 1m 16s
# 170:	learn: 0.1056576	total: 15.6s	remaining: 1m 15s
# 171:	learn: 0.1050950	total: 15.7s	remaining: 1m 15s
# 172:	learn: 0.1046837	total: 15.8s	remaining: 1m 15s
# 173:	learn: 0.1044791	total: 15.8s	remaining: 1m 15s
# 174:	learn: 0.1042178	total: 15.9s	remaining: 1m 14s
# 175:	learn: 0.1035441	total: 16s	remaining: 1m 14s
# 176:	learn: 0.1032026	total: 16s	remaining: 1m 14s
# 177:	learn: 0.1027619	total: 16.1s	remaining: 1m 14s
# 178:	learn: 0.1025276	total: 16.2s	remaining: 1m 14s
# 179:	learn: 0.1019434	total: 16.2s	remaining: 1m 13s
# 180:	learn: 0.1017408	total: 16.3s	remaining: 1m 13s
# 181:	learn: 0.1011068	total: 16.4s	remaining: 1m 13s
# 182:	learn: 0.1007804	total: 16.4s	remaining: 1m 13s
# 183:	learn: 0.1003209	total: 16.5s	remaining: 1m 13s
# 184:	learn: 0.0995848	total: 16.6s	remaining: 1m 12s
# 185:	learn: 0.0990240	total: 16.6s	remaining: 1m 12s
# 186:	learn: 0.0986706	total: 16.7s	remaining: 1m 12s
# 187:	learn: 0.0979531	total: 16.8s	remaining: 1m 12s
# 188:	learn: 0.0975490	total: 16.9s	remaining: 1m 12s
# 189:	learn: 0.0972096	total: 16.9s	remaining: 1m 12s
# 190:	learn: 0.0966210	total: 17s	remaining: 1m 12s
# 191:	learn: 0.0963604	total: 17.1s	remaining: 1m 11s
# 192:	learn: 0.0959756	total: 17.1s	remaining: 1m 11s
# 193:	learn: 0.0955980	total: 17.2s	remaining: 1m 11s
# 194:	learn: 0.0952790	total: 17.3s	remaining: 1m 11s
# 195:	learn: 0.0950225	total: 17.3s	remaining: 1m 11s
# 196:	learn: 0.0945239	total: 17.4s	remaining: 1m 10s
# 197:	learn: 0.0943742	total: 17.5s	remaining: 1m 10s
# 198:	learn: 0.0938250	total: 17.5s	remaining: 1m 10s
# 199:	learn: 0.0934920	total: 17.6s	remaining: 1m 10s
# 200:	learn: 0.0930585	total: 17.6s	remaining: 1m 10s
# 201:	learn: 0.0927522	total: 17.7s	remaining: 1m 9s
# 202:	learn: 0.0925827	total: 17.7s	remaining: 1m 9s
# 203:	learn: 0.0923716	total: 17.8s	remaining: 1m 9s
# 204:	learn: 0.0918546	total: 17.9s	remaining: 1m 9s
# 205:	learn: 0.0916775	total: 17.9s	remaining: 1m 9s
# 206:	learn: 0.0914830	total: 18s	remaining: 1m 8s
# 207:	learn: 0.0907512	total: 18.1s	remaining: 1m 8s
# 208:	learn: 0.0903056	total: 18.1s	remaining: 1m 8s
# 209:	learn: 0.0899399	total: 18.2s	remaining: 1m 8s
# 210:	learn: 0.0896049	total: 18.2s	remaining: 1m 8s
# 211:	learn: 0.0893776	total: 18.3s	remaining: 1m 7s
# 212:	learn: 0.0890453	total: 18.4s	remaining: 1m 7s
# 213:	learn: 0.0885533	total: 18.4s	remaining: 1m 7s
# 214:	learn: 0.0882819	total: 18.5s	remaining: 1m 7s
# 215:	learn: 0.0880558	total: 18.5s	remaining: 1m 7s
# 216:	learn: 0.0877029	total: 18.6s	remaining: 1m 7s
# 217:	learn: 0.0870744	total: 18.7s	remaining: 1m 6s
# 218:	learn: 0.0865749	total: 18.7s	remaining: 1m 6s
# 219:	learn: 0.0862641	total: 18.8s	remaining: 1m 6s
# 220:	learn: 0.0859850	total: 18.8s	remaining: 1m 6s
# 221:	learn: 0.0856473	total: 18.9s	remaining: 1m 6s
# 222:	learn: 0.0852322	total: 18.9s	remaining: 1m 6s
# 223:	learn: 0.0845748	total: 19s	remaining: 1m 5s
# 224:	learn: 0.0844979	total: 19.1s	remaining: 1m 5s
# 225:	learn: 0.0839091	total: 19.1s	remaining: 1m 5s
# 226:	learn: 0.0834455	total: 19.3s	remaining: 1m 5s
# 227:	learn: 0.0832137	total: 19.4s	remaining: 1m 5s
# 228:	learn: 0.0827852	total: 19.6s	remaining: 1m 5s
# 229:	learn: 0.0825247	total: 19.7s	remaining: 1m 6s
# 230:	learn: 0.0821260	total: 19.8s	remaining: 1m 5s
# 231:	learn: 0.0817082	total: 19.9s	remaining: 1m 5s
# 232:	learn: 0.0812137	total: 20s	remaining: 1m 5s
# 233:	learn: 0.0810368	total: 20.1s	remaining: 1m 5s
# 234:	learn: 0.0805174	total: 20.1s	remaining: 1m 5s
# 235:	learn: 0.0802756	total: 20.2s	remaining: 1m 5s
# 236:	learn: 0.0801356	total: 20.3s	remaining: 1m 5s
# 237:	learn: 0.0799684	total: 20.4s	remaining: 1m 5s
# 238:	learn: 0.0797375	total: 20.4s	remaining: 1m 4s
# 239:	learn: 0.0792948	total: 20.5s	remaining: 1m 4s
# 240:	learn: 0.0791254	total: 20.5s	remaining: 1m 4s
# 241:	learn: 0.0788761	total: 20.6s	remaining: 1m 4s
# 242:	learn: 0.0785406	total: 20.6s	remaining: 1m 4s
# 243:	learn: 0.0783030	total: 20.7s	remaining: 1m 4s
# 244:	learn: 0.0781131	total: 20.8s	remaining: 1m 3s
# 245:	learn: 0.0779718	total: 20.8s	remaining: 1m 3s
# 246:	learn: 0.0776109	total: 20.9s	remaining: 1m 3s
# 247:	learn: 0.0775374	total: 20.9s	remaining: 1m 3s
# 248:	learn: 0.0773135	total: 21s	remaining: 1m 3s
# 249:	learn: 0.0769048	total: 21.1s	remaining: 1m 3s
# 250:	learn: 0.0765547	total: 21.1s	remaining: 1m 2s
# 251:	learn: 0.0764374	total: 21.2s	remaining: 1m 2s
# 252:	learn: 0.0762860	total: 21.2s	remaining: 1m 2s
# 253:	learn: 0.0761586	total: 21.3s	remaining: 1m 2s
# 254:	learn: 0.0759847	total: 21.4s	remaining: 1m 2s
# 255:	learn: 0.0757023	total: 21.5s	remaining: 1m 2s
# 256:	learn: 0.0753828	total: 21.6s	remaining: 1m 2s
# 257:	learn: 0.0751061	total: 21.6s	remaining: 1m 2s
# 258:	learn: 0.0749455	total: 21.7s	remaining: 1m 2s
# 259:	learn: 0.0745573	total: 21.8s	remaining: 1m 1s
# 260:	learn: 0.0742632	total: 21.8s	remaining: 1m 1s
# 261:	learn: 0.0740965	total: 22s	remaining: 1m 1s
# 262:	learn: 0.0737763	total: 22.1s	remaining: 1m 1s
# 263:	learn: 0.0735961	total: 22.2s	remaining: 1m 1s
# 264:	learn: 0.0732907	total: 22.3s	remaining: 1m 1s
# 265:	learn: 0.0729339	total: 22.4s	remaining: 1m 1s
# 266:	learn: 0.0725681	total: 22.5s	remaining: 1m 1s
# 267:	learn: 0.0723479	total: 22.6s	remaining: 1m 1s
# 268:	learn: 0.0721680	total: 22.7s	remaining: 1m 1s
# 269:	learn: 0.0719300	total: 22.8s	remaining: 1m 1s
# 270:	learn: 0.0718516	total: 22.9s	remaining: 1m 1s
# 271:	learn: 0.0717007	total: 23s	remaining: 1m 1s
# 272:	learn: 0.0714915	total: 23.1s	remaining: 1m 1s
# 273:	learn: 0.0711155	total: 23.2s	remaining: 1m 1s
# 274:	learn: 0.0709471	total: 23.3s	remaining: 1m 1s
# 275:	learn: 0.0708069	total: 23.4s	remaining: 1m 1s
# 276:	learn: 0.0706434	total: 23.4s	remaining: 1m 1s
# 277:	learn: 0.0704186	total: 23.5s	remaining: 1m
# 278:	learn: 0.0701726	total: 23.5s	remaining: 1m
# 279:	learn: 0.0699641	total: 23.6s	remaining: 1m
# 280:	learn: 0.0698096	total: 23.7s	remaining: 1m
# 281:	learn: 0.0696274	total: 23.7s	remaining: 1m
# 282:	learn: 0.0693420	total: 23.8s	remaining: 1m
# 283:	learn: 0.0693085	total: 23.9s	remaining: 1m
# 284:	learn: 0.0690634	total: 23.9s	remaining: 60s
# 285:	learn: 0.0689074	total: 24s	remaining: 59.8s
# 286:	learn: 0.0686698	total: 24s	remaining: 59.7s
# 287:	learn: 0.0685188	total: 24.1s	remaining: 59.5s
# 288:	learn: 0.0682657	total: 24.1s	remaining: 59.4s
# 289:	learn: 0.0678924	total: 24.2s	remaining: 59.2s
# 290:	learn: 0.0676314	total: 24.2s	remaining: 59.1s
# 291:	learn: 0.0674669	total: 24.3s	remaining: 58.9s
# 292:	learn: 0.0673068	total: 24.4s	remaining: 58.8s
# 293:	learn: 0.0671341	total: 24.4s	remaining: 58.7s
# 294:	learn: 0.0667767	total: 24.5s	remaining: 58.5s
# 295:	learn: 0.0664980	total: 24.5s	remaining: 58.4s
# 296:	learn: 0.0662858	total: 24.6s	remaining: 58.2s
# 297:	learn: 0.0661728	total: 24.7s	remaining: 58.1s
# 298:	learn: 0.0660745	total: 24.7s	remaining: 58s
# 299:	learn: 0.0658713	total: 24.8s	remaining: 57.8s
# 300:	learn: 0.0657761	total: 24.8s	remaining: 57.7s
# 301:	learn: 0.0656474	total: 24.9s	remaining: 57.6s
# 302:	learn: 0.0653968	total: 25s	remaining: 57.5s
# 303:	learn: 0.0652111	total: 25.1s	remaining: 57.5s
# 304:	learn: 0.0649948	total: 25.2s	remaining: 57.4s
# 305:	learn: 0.0647301	total: 25.3s	remaining: 57.4s
# 306:	learn: 0.0645364	total: 25.4s	remaining: 57.3s
# 307:	learn: 0.0643730	total: 25.6s	remaining: 57.5s
# 308:	learn: 0.0642647	total: 25.7s	remaining: 57.5s
# 309:	learn: 0.0640801	total: 25.8s	remaining: 57.4s
# 310:	learn: 0.0639659	total: 25.9s	remaining: 57.3s
# 311:	learn: 0.0637517	total: 26s	remaining: 57.3s
# 312:	learn: 0.0636550	total: 26.1s	remaining: 57.3s
# 313:	learn: 0.0635446	total: 26.2s	remaining: 57.2s
# 314:	learn: 0.0634244	total: 26.3s	remaining: 57.1s
# 315:	learn: 0.0630064	total: 26.3s	remaining: 57s
# 316:	learn: 0.0628817	total: 26.4s	remaining: 56.9s
# 317:	learn: 0.0627567	total: 26.5s	remaining: 56.8s
# 318:	learn: 0.0624933	total: 26.6s	remaining: 56.9s
# 319:	learn: 0.0620853	total: 26.8s	remaining: 56.9s
# 320:	learn: 0.0619375	total: 26.9s	remaining: 56.8s
# 321:	learn: 0.0617239	total: 27s	remaining: 56.8s
# 322:	learn: 0.0615191	total: 27.1s	remaining: 56.7s
# 323:	learn: 0.0613870	total: 27.2s	remaining: 56.7s
# 324:	learn: 0.0611792	total: 27.4s	remaining: 56.8s
# 325:	learn: 0.0610240	total: 27.5s	remaining: 56.8s
# 326:	learn: 0.0608795	total: 27.5s	remaining: 56.7s
# 327:	learn: 0.0606113	total: 27.6s	remaining: 56.5s
# 328:	learn: 0.0603969	total: 27.7s	remaining: 56.4s
# 329:	learn: 0.0602929	total: 27.7s	remaining: 56.3s
# 330:	learn: 0.0601321	total: 27.8s	remaining: 56.2s
# 331:	learn: 0.0600233	total: 27.8s	remaining: 56s
# 332:	learn: 0.0598825	total: 27.9s	remaining: 55.9s
# 333:	learn: 0.0598191	total: 28s	remaining: 55.8s
# 334:	learn: 0.0595921	total: 28.1s	remaining: 55.7s
# 335:	learn: 0.0593861	total: 28.2s	remaining: 55.8s
# 336:	learn: 0.0591955	total: 28.4s	remaining: 55.8s
# 337:	learn: 0.0589065	total: 28.4s	remaining: 55.7s
# 338:	learn: 0.0587332	total: 28.5s	remaining: 55.6s
# 339:	learn: 0.0585098	total: 28.6s	remaining: 55.4s
# 340:	learn: 0.0582836	total: 28.6s	remaining: 55.3s
# 341:	learn: 0.0581345	total: 28.7s	remaining: 55.2s
# 342:	learn: 0.0579695	total: 28.8s	remaining: 55.2s
# 343:	learn: 0.0577229	total: 28.9s	remaining: 55.1s
# 344:	learn: 0.0575562	total: 29s	remaining: 55s
# 345:	learn: 0.0573366	total: 29.1s	remaining: 54.9s
# 346:	learn: 0.0571973	total: 29.1s	remaining: 54.8s
# 347:	learn: 0.0567509	total: 29.2s	remaining: 54.7s
# 348:	learn: 0.0565171	total: 29.3s	remaining: 54.6s
# 349:	learn: 0.0562078	total: 29.4s	remaining: 54.5s
# 350:	learn: 0.0558955	total: 29.4s	remaining: 54.4s
# 351:	learn: 0.0556589	total: 29.5s	remaining: 54.3s
# 352:	learn: 0.0555017	total: 29.6s	remaining: 54.3s
# 353:	learn: 0.0553492	total: 29.7s	remaining: 54.2s
# 354:	learn: 0.0552628	total: 29.8s	remaining: 54.1s
# 355:	learn: 0.0551789	total: 29.9s	remaining: 54s
# 356:	learn: 0.0550581	total: 29.9s	remaining: 53.9s
# 357:	learn: 0.0549338	total: 30s	remaining: 53.8s
# 358:	learn: 0.0547836	total: 30.1s	remaining: 53.8s
# 359:	learn: 0.0546948	total: 30.2s	remaining: 53.7s
# 360:	learn: 0.0544964	total: 30.2s	remaining: 53.5s
# 361:	learn: 0.0543440	total: 30.3s	remaining: 53.4s
# 362:	learn: 0.0542287	total: 30.4s	remaining: 53.3s
# 363:	learn: 0.0541137	total: 30.4s	remaining: 53.2s
# 364:	learn: 0.0539949	total: 30.5s	remaining: 53.1s
# 365:	learn: 0.0539340	total: 30.6s	remaining: 52.9s
# 366:	learn: 0.0538399	total: 30.6s	remaining: 52.8s
# 367:	learn: 0.0537419	total: 30.7s	remaining: 52.7s
# 368:	learn: 0.0534806	total: 30.8s	remaining: 52.6s
# 369:	learn: 0.0532836	total: 30.8s	remaining: 52.5s
# 370:	learn: 0.0530877	total: 30.9s	remaining: 52.3s
# 371:	learn: 0.0529235	total: 30.9s	remaining: 52.2s
# 372:	learn: 0.0527600	total: 31s	remaining: 52.1s
# 373:	learn: 0.0526299	total: 31.1s	remaining: 52s
# 374:	learn: 0.0525197	total: 31.1s	remaining: 51.9s
# 375:	learn: 0.0524544	total: 31.2s	remaining: 51.8s
# 376:	learn: 0.0523124	total: 31.3s	remaining: 51.7s
# 377:	learn: 0.0521551	total: 31.3s	remaining: 51.6s
# 378:	learn: 0.0520704	total: 31.4s	remaining: 51.5s
# 379:	learn: 0.0519297	total: 31.5s	remaining: 51.3s
# 380:	learn: 0.0517689	total: 31.5s	remaining: 51.2s
# 381:	learn: 0.0516434	total: 31.6s	remaining: 51.1s
# 382:	learn: 0.0515078	total: 31.7s	remaining: 51.1s
# 383:	learn: 0.0514325	total: 31.8s	remaining: 50.9s
# 384:	learn: 0.0512908	total: 31.8s	remaining: 50.8s
# 385:	learn: 0.0512391	total: 31.9s	remaining: 50.7s
# 386:	learn: 0.0510966	total: 32s	remaining: 50.6s
# 387:	learn: 0.0509657	total: 32s	remaining: 50.5s
# 388:	learn: 0.0507371	total: 32.1s	remaining: 50.4s
# 389:	learn: 0.0505807	total: 32.1s	remaining: 50.3s
# 390:	learn: 0.0504632	total: 32.2s	remaining: 50.2s
# 391:	learn: 0.0503096	total: 32.3s	remaining: 50.1s
# 392:	learn: 0.0502296	total: 32.3s	remaining: 50s
# 393:	learn: 0.0500643	total: 32.4s	remaining: 49.9s
# 394:	learn: 0.0498900	total: 32.5s	remaining: 49.7s
# 395:	learn: 0.0497966	total: 32.5s	remaining: 49.6s
# 396:	learn: 0.0496380	total: 32.6s	remaining: 49.5s
# 397:	learn: 0.0494989	total: 32.7s	remaining: 49.4s
# 398:	learn: 0.0493426	total: 32.7s	remaining: 49.3s
# 399:	learn: 0.0491180	total: 32.8s	remaining: 49.2s
# 400:	learn: 0.0489101	total: 32.9s	remaining: 49.1s
# 401:	learn: 0.0488058	total: 32.9s	remaining: 49s
# 402:	learn: 0.0486918	total: 33s	remaining: 48.8s
# 403:	learn: 0.0485737	total: 33s	remaining: 48.7s
# 404:	learn: 0.0484627	total: 33.1s	remaining: 48.6s
# 405:	learn: 0.0482988	total: 33.2s	remaining: 48.5s
# 406:	learn: 0.0481965	total: 33.2s	remaining: 48.4s
# 407:	learn: 0.0480682	total: 33.3s	remaining: 48.3s
# 408:	learn: 0.0479270	total: 33.3s	remaining: 48.2s
# 409:	learn: 0.0477782	total: 33.4s	remaining: 48.1s
# 410:	learn: 0.0476616	total: 33.5s	remaining: 47.9s
# 411:	learn: 0.0474628	total: 33.5s	remaining: 47.8s
# 412:	learn: 0.0473122	total: 33.6s	remaining: 47.7s
# 413:	learn: 0.0471784	total: 33.6s	remaining: 47.6s
# 414:	learn: 0.0470762	total: 33.7s	remaining: 47.5s
# 415:	learn: 0.0469096	total: 33.8s	remaining: 47.4s
# 416:	learn: 0.0468256	total: 33.8s	remaining: 47.3s
# 417:	learn: 0.0466974	total: 33.9s	remaining: 47.2s
# 418:	learn: 0.0465870	total: 33.9s	remaining: 47.1s
# 419:	learn: 0.0465292	total: 34.1s	remaining: 47.1s
# 420:	learn: 0.0464846	total: 34.2s	remaining: 47s
# 421:	learn: 0.0463614	total: 34.3s	remaining: 46.9s
# 422:	learn: 0.0461421	total: 34.3s	remaining: 46.8s
# 423:	learn: 0.0460704	total: 34.4s	remaining: 46.8s
# 424:	learn: 0.0459933	total: 34.5s	remaining: 46.7s
# 425:	learn: 0.0458664	total: 34.7s	remaining: 46.8s
# 426:	learn: 0.0457081	total: 34.8s	remaining: 46.7s
# 427:	learn: 0.0455100	total: 34.9s	remaining: 46.7s
# 428:	learn: 0.0453461	total: 35s	remaining: 46.6s
# 429:	learn: 0.0452042	total: 35.2s	remaining: 46.7s
# 430:	learn: 0.0450330	total: 35.4s	remaining: 46.7s
# 431:	learn: 0.0448609	total: 35.4s	remaining: 46.6s
# 432:	learn: 0.0447198	total: 35.5s	remaining: 46.5s
# 433:	learn: 0.0446174	total: 35.6s	remaining: 46.4s
# 434:	learn: 0.0443946	total: 35.7s	remaining: 46.4s
# 435:	learn: 0.0442938	total: 35.8s	remaining: 46.3s
# 436:	learn: 0.0441967	total: 35.9s	remaining: 46.2s
# 437:	learn: 0.0441096	total: 35.9s	remaining: 46.1s
# 438:	learn: 0.0440149	total: 36s	remaining: 46s
# 439:	learn: 0.0438170	total: 36s	remaining: 45.9s
# 440:	learn: 0.0437232	total: 36.1s	remaining: 45.8s
# 441:	learn: 0.0435983	total: 36.2s	remaining: 45.7s
# 442:	learn: 0.0435251	total: 36.2s	remaining: 45.6s
# 443:	learn: 0.0434563	total: 36.3s	remaining: 45.5s
# 444:	learn: 0.0433817	total: 36.4s	remaining: 45.4s
# 445:	learn: 0.0433504	total: 36.4s	remaining: 45.3s
# 446:	learn: 0.0432463	total: 36.5s	remaining: 45.2s
# 447:	learn: 0.0432127	total: 36.6s	remaining: 45s
# 448:	learn: 0.0430874	total: 36.6s	remaining: 44.9s
# 449:	learn: 0.0429516	total: 36.7s	remaining: 44.8s
# 450:	learn: 0.0427704	total: 36.7s	remaining: 44.7s
# 451:	learn: 0.0427052	total: 36.8s	remaining: 44.6s
# 452:	learn: 0.0425878	total: 36.9s	remaining: 44.5s
# 453:	learn: 0.0425414	total: 36.9s	remaining: 44.4s
# 454:	learn: 0.0424232	total: 37s	remaining: 44.3s
# 455:	learn: 0.0423415	total: 37.1s	remaining: 44.2s
# 456:	learn: 0.0422262	total: 37.1s	remaining: 44.1s
# 457:	learn: 0.0421116	total: 37.2s	remaining: 44s
# 458:	learn: 0.0420900	total: 37.3s	remaining: 43.9s
# 459:	learn: 0.0419750	total: 37.3s	remaining: 43.8s
# 460:	learn: 0.0419058	total: 37.4s	remaining: 43.7s
# 461:	learn: 0.0417958	total: 37.5s	remaining: 43.7s
# 462:	learn: 0.0416884	total: 37.6s	remaining: 43.6s
# 463:	learn: 0.0415780	total: 37.6s	remaining: 43.5s
# 464:	learn: 0.0414557	total: 37.7s	remaining: 43.4s
# 465:	learn: 0.0413051	total: 37.8s	remaining: 43.3s
# 466:	learn: 0.0412533	total: 37.8s	remaining: 43.2s
# 467:	learn: 0.0411485	total: 37.9s	remaining: 43.1s
# 468:	learn: 0.0410647	total: 38s	remaining: 43s
# 469:	learn: 0.0409714	total: 38s	remaining: 42.9s
# 470:	learn: 0.0408461	total: 38.1s	remaining: 42.8s
# 471:	learn: 0.0407621	total: 38.2s	remaining: 42.7s
# 472:	learn: 0.0405966	total: 38.3s	remaining: 42.7s
# 473:	learn: 0.0404784	total: 38.5s	remaining: 42.7s
# 474:	learn: 0.0403413	total: 38.6s	remaining: 42.7s
# 475:	learn: 0.0402256	total: 38.7s	remaining: 42.6s
# 476:	learn: 0.0401552	total: 38.8s	remaining: 42.6s
# 477:	learn: 0.0399726	total: 38.9s	remaining: 42.5s
# 478:	learn: 0.0398311	total: 39s	remaining: 42.4s
# 479:	learn: 0.0397688	total: 39.1s	remaining: 42.4s
# 480:	learn: 0.0396539	total: 39.2s	remaining: 42.3s
# 481:	learn: 0.0395674	total: 39.3s	remaining: 42.2s
# 482:	learn: 0.0394431	total: 39.4s	remaining: 42.2s
# 483:	learn: 0.0393837	total: 39.5s	remaining: 42.1s
# 484:	learn: 0.0392522	total: 39.5s	remaining: 42s
# 485:	learn: 0.0391253	total: 39.6s	remaining: 41.9s
# 486:	learn: 0.0390870	total: 39.7s	remaining: 41.8s
# 487:	learn: 0.0389833	total: 39.8s	remaining: 41.7s
# 488:	learn: 0.0389177	total: 39.8s	remaining: 41.6s
# 489:	learn: 0.0388378	total: 39.9s	remaining: 41.5s
# 490:	learn: 0.0387253	total: 40s	remaining: 41.4s
# 491:	learn: 0.0385755	total: 40s	remaining: 41.3s
# 492:	learn: 0.0385141	total: 40.1s	remaining: 41.2s
# 493:	learn: 0.0383677	total: 40.2s	remaining: 41.1s
# 494:	learn: 0.0383078	total: 40.2s	remaining: 41s
# 495:	learn: 0.0382592	total: 40.3s	remaining: 40.9s
# 496:	learn: 0.0381935	total: 40.4s	remaining: 40.8s
# 497:	learn: 0.0381091	total: 40.4s	remaining: 40.7s
# 498:	learn: 0.0379340	total: 40.5s	remaining: 40.6s
# 499:	learn: 0.0378614	total: 40.5s	remaining: 40.5s
# 500:	learn: 0.0377880	total: 40.6s	remaining: 40.5s
# 501:	learn: 0.0377036	total: 40.7s	remaining: 40.4s
# 502:	learn: 0.0375794	total: 40.8s	remaining: 40.3s
# 503:	learn: 0.0375367	total: 40.8s	remaining: 40.2s
# 504:	learn: 0.0374844	total: 40.9s	remaining: 40.1s
# 505:	learn: 0.0374223	total: 41s	remaining: 40s
# 506:	learn: 0.0373428	total: 41.1s	remaining: 39.9s
# 507:	learn: 0.0372440	total: 41.2s	remaining: 39.9s
# 508:	learn: 0.0371202	total: 41.2s	remaining: 39.8s
# 509:	learn: 0.0369790	total: 41.3s	remaining: 39.7s
# 510:	learn: 0.0368216	total: 41.4s	remaining: 39.6s
# 511:	learn: 0.0367668	total: 41.4s	remaining: 39.5s
# 512:	learn: 0.0366146	total: 41.5s	remaining: 39.4s
# 513:	learn: 0.0365410	total: 41.6s	remaining: 39.3s
# 514:	learn: 0.0364290	total: 41.6s	remaining: 39.2s
# 515:	learn: 0.0363760	total: 41.7s	remaining: 39.1s
# 516:	learn: 0.0362907	total: 41.8s	remaining: 39s
# 517:	learn: 0.0362040	total: 41.8s	remaining: 38.9s
# 518:	learn: 0.0361525	total: 41.9s	remaining: 38.8s
# 519:	learn: 0.0360577	total: 41.9s	remaining: 38.7s
# 520:	learn: 0.0360217	total: 42s	remaining: 38.6s
# 521:	learn: 0.0359753	total: 42.1s	remaining: 38.5s
# 522:	learn: 0.0358597	total: 42.1s	remaining: 38.4s
# 523:	learn: 0.0357571	total: 42.2s	remaining: 38.3s
# 524:	learn: 0.0356728	total: 42.2s	remaining: 38.2s
# 525:	learn: 0.0355723	total: 42.3s	remaining: 38.1s
# 526:	learn: 0.0355048	total: 42.4s	remaining: 38s
# 527:	learn: 0.0354362	total: 42.4s	remaining: 37.9s
# 528:	learn: 0.0353924	total: 42.5s	remaining: 37.8s
# 529:	learn: 0.0353388	total: 42.5s	remaining: 37.7s
# 530:	learn: 0.0352717	total: 42.6s	remaining: 37.6s
# 531:	learn: 0.0352326	total: 42.7s	remaining: 37.5s
# 532:	learn: 0.0351532	total: 42.7s	remaining: 37.4s
# 533:	learn: 0.0350987	total: 42.8s	remaining: 37.3s
# 534:	learn: 0.0350177	total: 42.8s	remaining: 37.2s
# 535:	learn: 0.0349620	total: 42.9s	remaining: 37.1s
# 536:	learn: 0.0348796	total: 43s	remaining: 37.1s
# 537:	learn: 0.0346812	total: 43.1s	remaining: 37s
# 538:	learn: 0.0345829	total: 43.1s	remaining: 36.9s
# 539:	learn: 0.0345062	total: 43.2s	remaining: 36.8s
# 540:	learn: 0.0344079	total: 43.3s	remaining: 36.7s
# 541:	learn: 0.0343327	total: 43.4s	remaining: 36.6s
# 542:	learn: 0.0342971	total: 43.4s	remaining: 36.5s
# 543:	learn: 0.0342466	total: 43.5s	remaining: 36.4s
# 544:	learn: 0.0341365	total: 43.5s	remaining: 36.4s
# 545:	learn: 0.0340619	total: 43.6s	remaining: 36.3s
# 546:	learn: 0.0339747	total: 43.7s	remaining: 36.2s
# 547:	learn: 0.0339107	total: 43.8s	remaining: 36.1s
# 548:	learn: 0.0338634	total: 43.8s	remaining: 36s
# 549:	learn: 0.0337579	total: 43.9s	remaining: 35.9s
# 550:	learn: 0.0337156	total: 44s	remaining: 35.8s
# 551:	learn: 0.0335655	total: 44s	remaining: 35.7s
# 552:	learn: 0.0334229	total: 44.1s	remaining: 35.6s
# 553:	learn: 0.0333397	total: 44.2s	remaining: 35.5s
# 554:	learn: 0.0332534	total: 44.2s	remaining: 35.5s
# 555:	learn: 0.0331374	total: 44.3s	remaining: 35.4s
# 556:	learn: 0.0330484	total: 44.3s	remaining: 35.3s
# 557:	learn: 0.0329768	total: 44.4s	remaining: 35.2s
# 558:	learn: 0.0328788	total: 44.5s	remaining: 35.1s
# 559:	learn: 0.0328153	total: 44.5s	remaining: 35s
# 560:	learn: 0.0327426	total: 44.6s	remaining: 34.9s
# 561:	learn: 0.0326977	total: 44.6s	remaining: 34.8s
# 562:	learn: 0.0326158	total: 44.7s	remaining: 34.7s
# 563:	learn: 0.0324973	total: 44.8s	remaining: 34.6s
# 564:	learn: 0.0324519	total: 44.8s	remaining: 34.5s
# 565:	learn: 0.0324079	total: 44.9s	remaining: 34.4s
# 566:	learn: 0.0322737	total: 45s	remaining: 34.3s
# 567:	learn: 0.0322058	total: 45s	remaining: 34.2s
# 568:	learn: 0.0320787	total: 45.1s	remaining: 34.1s
# 569:	learn: 0.0320445	total: 45.1s	remaining: 34s
# 570:	learn: 0.0319152	total: 45.2s	remaining: 33.9s
# 571:	learn: 0.0318871	total: 45.2s	remaining: 33.8s
# 572:	learn: 0.0318209	total: 45.3s	remaining: 33.8s
# 573:	learn: 0.0317904	total: 45.4s	remaining: 33.7s
# 574:	learn: 0.0317012	total: 45.4s	remaining: 33.6s
# 575:	learn: 0.0316111	total: 45.5s	remaining: 33.5s
# 576:	learn: 0.0315562	total: 45.5s	remaining: 33.4s
# 577:	learn: 0.0315125	total: 45.6s	remaining: 33.3s
# 578:	learn: 0.0314752	total: 45.7s	remaining: 33.2s
# 579:	learn: 0.0314066	total: 45.7s	remaining: 33.1s
# 580:	learn: 0.0313037	total: 45.8s	remaining: 33s
# 581:	learn: 0.0311951	total: 45.8s	remaining: 32.9s
# 582:	learn: 0.0311524	total: 45.9s	remaining: 32.8s
# 583:	learn: 0.0311076	total: 46s	remaining: 32.7s
# 584:	learn: 0.0310673	total: 46s	remaining: 32.7s
# 585:	learn: 0.0310165	total: 46.1s	remaining: 32.6s
# 586:	learn: 0.0309143	total: 46.2s	remaining: 32.5s
# 587:	learn: 0.0308509	total: 46.2s	remaining: 32.4s
# 588:	learn: 0.0307773	total: 46.3s	remaining: 32.3s
# 589:	learn: 0.0307338	total: 46.4s	remaining: 32.2s
# 590:	learn: 0.0306789	total: 46.4s	remaining: 32.1s
# 591:	learn: 0.0305716	total: 46.5s	remaining: 32s
# 592:	learn: 0.0305151	total: 46.6s	remaining: 32s
# 593:	learn: 0.0304575	total: 46.6s	remaining: 31.9s
# 594:	learn: 0.0303805	total: 46.7s	remaining: 31.8s
# 595:	learn: 0.0303145	total: 46.8s	remaining: 31.7s
# 596:	learn: 0.0302830	total: 46.8s	remaining: 31.6s
# 597:	learn: 0.0301945	total: 46.9s	remaining: 31.5s
# 598:	learn: 0.0301426	total: 47s	remaining: 31.5s
# 599:	learn: 0.0300975	total: 47.1s	remaining: 31.4s
# 600:	learn: 0.0300503	total: 47.1s	remaining: 31.3s
# 601:	learn: 0.0299472	total: 47.2s	remaining: 31.2s
# 602:	learn: 0.0299156	total: 47.3s	remaining: 31.1s
# 603:	learn: 0.0298594	total: 47.3s	remaining: 31s
# 604:	learn: 0.0297189	total: 47.4s	remaining: 30.9s
# 605:	learn: 0.0296782	total: 47.4s	remaining: 30.8s
# 606:	learn: 0.0296368	total: 47.5s	remaining: 30.8s
# 607:	learn: 0.0295967	total: 47.6s	remaining: 30.7s
# 608:	learn: 0.0295509	total: 47.6s	remaining: 30.6s
# 609:	learn: 0.0294914	total: 47.7s	remaining: 30.5s
# 610:	learn: 0.0294410	total: 47.8s	remaining: 30.4s
# 611:	learn: 0.0293720	total: 47.8s	remaining: 30.3s
# 612:	learn: 0.0293422	total: 47.9s	remaining: 30.2s
# 613:	learn: 0.0292675	total: 47.9s	remaining: 30.1s
# 614:	learn: 0.0291330	total: 48s	remaining: 30s
# 615:	learn: 0.0290579	total: 48.1s	remaining: 30s
# 616:	learn: 0.0289871	total: 48.1s	remaining: 29.9s
# 617:	learn: 0.0289179	total: 48.2s	remaining: 29.8s
# 618:	learn: 0.0288382	total: 48.2s	remaining: 29.7s
# 619:	learn: 0.0287819	total: 48.3s	remaining: 29.6s
# 620:	learn: 0.0287099	total: 48.4s	remaining: 29.5s
# 621:	learn: 0.0286650	total: 48.4s	remaining: 29.4s
# 622:	learn: 0.0286029	total: 48.5s	remaining: 29.3s
# 623:	learn: 0.0285296	total: 48.5s	remaining: 29.3s
# 624:	learn: 0.0284257	total: 48.6s	remaining: 29.2s
# 625:	learn: 0.0283278	total: 48.7s	remaining: 29.1s
# 626:	learn: 0.0282669	total: 48.7s	remaining: 29s
# 627:	learn: 0.0282010	total: 48.8s	remaining: 28.9s
# 628:	learn: 0.0280824	total: 48.9s	remaining: 28.8s
# 629:	learn: 0.0280369	total: 48.9s	remaining: 28.7s
# 630:	learn: 0.0279966	total: 49s	remaining: 28.6s
# 631:	learn: 0.0279435	total: 49.1s	remaining: 28.6s
# 632:	learn: 0.0279259	total: 49.1s	remaining: 28.5s
# 633:	learn: 0.0278622	total: 49.2s	remaining: 28.4s
# 634:	learn: 0.0278217	total: 49.2s	remaining: 28.3s
# 635:	learn: 0.0277602	total: 49.3s	remaining: 28.2s
# 636:	learn: 0.0277138	total: 49.4s	remaining: 28.1s
# 637:	learn: 0.0276885	total: 49.4s	remaining: 28s
# 638:	learn: 0.0276602	total: 49.5s	remaining: 28s
# 639:	learn: 0.0276256	total: 49.6s	remaining: 27.9s
# 640:	learn: 0.0275760	total: 49.6s	remaining: 27.8s
# 641:	learn: 0.0275405	total: 49.7s	remaining: 27.7s
# 642:	learn: 0.0274916	total: 49.8s	remaining: 27.6s
# 643:	learn: 0.0274451	total: 49.8s	remaining: 27.6s
# 644:	learn: 0.0273966	total: 49.9s	remaining: 27.5s
# 645:	learn: 0.0273273	total: 50s	remaining: 27.4s
# 646:	learn: 0.0272997	total: 50s	remaining: 27.3s
# 647:	learn: 0.0272656	total: 50.1s	remaining: 27.2s
# 648:	learn: 0.0272158	total: 50.2s	remaining: 27.1s
# 649:	learn: 0.0271739	total: 50.2s	remaining: 27s
# 650:	learn: 0.0271009	total: 50.3s	remaining: 27s
# 651:	learn: 0.0270570	total: 50.4s	remaining: 26.9s
# 652:	learn: 0.0270067	total: 50.4s	remaining: 26.8s
# 653:	learn: 0.0269457	total: 50.5s	remaining: 26.7s
# 654:	learn: 0.0268904	total: 50.5s	remaining: 26.6s
# 655:	learn: 0.0268553	total: 50.6s	remaining: 26.5s
# 656:	learn: 0.0268111	total: 50.7s	remaining: 26.4s
# 657:	learn: 0.0267757	total: 50.7s	remaining: 26.4s
# 658:	learn: 0.0267504	total: 50.8s	remaining: 26.3s
# 659:	learn: 0.0267156	total: 50.8s	remaining: 26.2s
# 660:	learn: 0.0266893	total: 50.9s	remaining: 26.1s
# 661:	learn: 0.0266403	total: 51s	remaining: 26s
# 662:	learn: 0.0265469	total: 51s	remaining: 25.9s
# 663:	learn: 0.0265177	total: 51.1s	remaining: 25.8s
# 664:	learn: 0.0264832	total: 51.1s	remaining: 25.8s
# 665:	learn: 0.0264250	total: 51.2s	remaining: 25.7s
# 666:	learn: 0.0263887	total: 51.2s	remaining: 25.6s
# 667:	learn: 0.0263616	total: 51.3s	remaining: 25.5s
# 668:	learn: 0.0262911	total: 51.4s	remaining: 25.4s
# 669:	learn: 0.0262231	total: 51.4s	remaining: 25.3s
# 670:	learn: 0.0261502	total: 51.5s	remaining: 25.2s
# 671:	learn: 0.0260675	total: 51.5s	remaining: 25.2s
# 672:	learn: 0.0260262	total: 51.6s	remaining: 25.1s
# 673:	learn: 0.0259678	total: 51.7s	remaining: 25s
# 674:	learn: 0.0258997	total: 51.7s	remaining: 24.9s
# 675:	learn: 0.0258271	total: 51.8s	remaining: 24.8s
# 676:	learn: 0.0257717	total: 51.8s	remaining: 24.7s
# 677:	learn: 0.0257157	total: 51.9s	remaining: 24.6s
# 678:	learn: 0.0256824	total: 52s	remaining: 24.6s
# 679:	learn: 0.0256529	total: 52s	remaining: 24.5s
# 680:	learn: 0.0255911	total: 52.1s	remaining: 24.4s
# 681:	learn: 0.0255505	total: 52.2s	remaining: 24.3s
# 682:	learn: 0.0255073	total: 52.2s	remaining: 24.2s
# 683:	learn: 0.0254490	total: 52.3s	remaining: 24.2s
# 684:	learn: 0.0254028	total: 52.4s	remaining: 24.1s
# 685:	learn: 0.0253542	total: 52.4s	remaining: 24s
# 686:	learn: 0.0252968	total: 52.5s	remaining: 23.9s
# 687:	learn: 0.0252432	total: 52.6s	remaining: 23.8s
# 688:	learn: 0.0252041	total: 52.6s	remaining: 23.8s
# 689:	learn: 0.0251530	total: 52.7s	remaining: 23.7s
# 690:	learn: 0.0250905	total: 52.8s	remaining: 23.6s
# 691:	learn: 0.0250334	total: 52.8s	remaining: 23.5s
# 692:	learn: 0.0249795	total: 52.9s	remaining: 23.4s
# 693:	learn: 0.0249158	total: 53s	remaining: 23.4s
# 694:	learn: 0.0248881	total: 53s	remaining: 23.3s
# 695:	learn: 0.0248381	total: 53.1s	remaining: 23.2s
# 696:	learn: 0.0247245	total: 53.2s	remaining: 23.1s
# 697:	learn: 0.0246468	total: 53.2s	remaining: 23s
# 698:	learn: 0.0246261	total: 53.3s	remaining: 23s
# 699:	learn: 0.0245816	total: 53.4s	remaining: 22.9s
# 700:	learn: 0.0245409	total: 53.4s	remaining: 22.8s
# 701:	learn: 0.0244706	total: 53.5s	remaining: 22.7s
# 702:	learn: 0.0244255	total: 53.5s	remaining: 22.6s
# 703:	learn: 0.0243943	total: 53.6s	remaining: 22.5s
# 704:	learn: 0.0243750	total: 53.7s	remaining: 22.5s
# 705:	learn: 0.0243180	total: 53.7s	remaining: 22.4s
# 706:	learn: 0.0242972	total: 53.8s	remaining: 22.3s
# 707:	learn: 0.0242701	total: 53.8s	remaining: 22.2s
# 708:	learn: 0.0242024	total: 53.9s	remaining: 22.1s
# 709:	learn: 0.0241559	total: 53.9s	remaining: 22s
# 710:	learn: 0.0241031	total: 54s	remaining: 21.9s
# 711:	learn: 0.0240746	total: 54.1s	remaining: 21.9s
# 712:	learn: 0.0240172	total: 54.1s	remaining: 21.8s
# 713:	learn: 0.0239733	total: 54.2s	remaining: 21.7s
# 714:	learn: 0.0239233	total: 54.2s	remaining: 21.6s
# 715:	learn: 0.0238574	total: 54.3s	remaining: 21.5s
# 716:	learn: 0.0238145	total: 54.4s	remaining: 21.5s
# 717:	learn: 0.0237539	total: 54.4s	remaining: 21.4s
# 718:	learn: 0.0237211	total: 54.5s	remaining: 21.3s
# 719:	learn: 0.0236457	total: 54.5s	remaining: 21.2s
# 720:	learn: 0.0236124	total: 54.6s	remaining: 21.1s
# 721:	learn: 0.0235818	total: 54.7s	remaining: 21s
# 722:	learn: 0.0235475	total: 54.7s	remaining: 21s
# 723:	learn: 0.0235319	total: 54.8s	remaining: 20.9s
# 724:	learn: 0.0234856	total: 54.8s	remaining: 20.8s
# 725:	learn: 0.0234483	total: 54.9s	remaining: 20.7s
# 726:	learn: 0.0233978	total: 55s	remaining: 20.6s
# 727:	learn: 0.0233615	total: 55s	remaining: 20.6s
# 728:	learn: 0.0233338	total: 55.1s	remaining: 20.5s
# 729:	learn: 0.0232993	total: 55.2s	remaining: 20.4s
# 730:	learn: 0.0232627	total: 55.2s	remaining: 20.3s
# 731:	learn: 0.0232313	total: 55.3s	remaining: 20.3s
# 732:	learn: 0.0231988	total: 55.4s	remaining: 20.2s
# 733:	learn: 0.0231012	total: 55.4s	remaining: 20.1s
# 734:	learn: 0.0230178	total: 55.5s	remaining: 20s
# 735:	learn: 0.0229686	total: 55.6s	remaining: 19.9s
# 736:	learn: 0.0229219	total: 55.6s	remaining: 19.9s
# 737:	learn: 0.0228658	total: 55.7s	remaining: 19.8s
# 738:	learn: 0.0227988	total: 55.8s	remaining: 19.7s
# 739:	learn: 0.0227286	total: 55.8s	remaining: 19.6s
# 740:	learn: 0.0226878	total: 55.9s	remaining: 19.5s
# 741:	learn: 0.0226493	total: 56s	remaining: 19.5s
# 742:	learn: 0.0226083	total: 56s	remaining: 19.4s
# 743:	learn: 0.0225777	total: 56.1s	remaining: 19.3s
# 744:	learn: 0.0225505	total: 56.2s	remaining: 19.2s
# 745:	learn: 0.0225197	total: 56.2s	remaining: 19.1s
# 746:	learn: 0.0224779	total: 56.3s	remaining: 19.1s
# 747:	learn: 0.0224618	total: 56.3s	remaining: 19s
# 748:	learn: 0.0224321	total: 56.4s	remaining: 18.9s
# 749:	learn: 0.0223789	total: 56.5s	remaining: 18.8s
# 750:	learn: 0.0223397	total: 56.5s	remaining: 18.7s
# 751:	learn: 0.0222982	total: 56.6s	remaining: 18.7s
# 752:	learn: 0.0222621	total: 56.6s	remaining: 18.6s
# 753:	learn: 0.0222198	total: 56.7s	remaining: 18.5s
# 754:	learn: 0.0221971	total: 56.7s	remaining: 18.4s
# 755:	learn: 0.0221288	total: 56.8s	remaining: 18.3s
# 756:	learn: 0.0221065	total: 56.9s	remaining: 18.3s
# 757:	learn: 0.0220644	total: 56.9s	remaining: 18.2s
# 758:	learn: 0.0219874	total: 57s	remaining: 18.1s
# 759:	learn: 0.0219481	total: 57.1s	remaining: 18s
# 760:	learn: 0.0219127	total: 57.1s	remaining: 17.9s
# 761:	learn: 0.0218748	total: 57.2s	remaining: 17.9s
# 762:	learn: 0.0218299	total: 57.2s	remaining: 17.8s
# 763:	learn: 0.0218133	total: 57.3s	remaining: 17.7s
# 764:	learn: 0.0217149	total: 57.4s	remaining: 17.6s
# 765:	learn: 0.0216381	total: 57.4s	remaining: 17.5s
# 766:	learn: 0.0216034	total: 57.5s	remaining: 17.5s
# 767:	learn: 0.0215752	total: 57.5s	remaining: 17.4s
# 768:	learn: 0.0215297	total: 57.6s	remaining: 17.3s
# 769:	learn: 0.0215020	total: 57.7s	remaining: 17.2s
# 770:	learn: 0.0214411	total: 57.7s	remaining: 17.1s
# 771:	learn: 0.0213951	total: 57.8s	remaining: 17.1s
# 772:	learn: 0.0213614	total: 57.9s	remaining: 17s
# 773:	learn: 0.0213181	total: 57.9s	remaining: 16.9s
# 774:	learn: 0.0212700	total: 58s	remaining: 16.8s
# 775:	learn: 0.0212398	total: 58.1s	remaining: 16.8s
# 776:	learn: 0.0211982	total: 58.2s	remaining: 16.7s
# 777:	learn: 0.0211588	total: 58.2s	remaining: 16.6s
# 778:	learn: 0.0211378	total: 58.3s	remaining: 16.5s
# 779:	learn: 0.0210570	total: 58.4s	remaining: 16.5s
# 780:	learn: 0.0210236	total: 58.4s	remaining: 16.4s
# 781:	learn: 0.0209906	total: 58.5s	remaining: 16.3s
# 782:	learn: 0.0209769	total: 58.6s	remaining: 16.2s
# 783:	learn: 0.0209286	total: 58.6s	remaining: 16.2s
# 784:	learn: 0.0209044	total: 58.7s	remaining: 16.1s
# 785:	learn: 0.0208605	total: 58.8s	remaining: 16s
# 786:	learn: 0.0208267	total: 58.8s	remaining: 15.9s
# 787:	learn: 0.0207736	total: 58.9s	remaining: 15.8s
# 788:	learn: 0.0206977	total: 59s	remaining: 15.8s
# 789:	learn: 0.0206754	total: 59s	remaining: 15.7s
# 790:	learn: 0.0206331	total: 59.1s	remaining: 15.6s
# 791:	learn: 0.0205789	total: 59.1s	remaining: 15.5s
# 792:	learn: 0.0204965	total: 59.2s	remaining: 15.5s
# 793:	learn: 0.0204723	total: 59.3s	remaining: 15.4s
# 794:	learn: 0.0204449	total: 59.3s	remaining: 15.3s
# 795:	learn: 0.0204099	total: 59.4s	remaining: 15.2s
# 796:	learn: 0.0203545	total: 59.5s	remaining: 15.1s
# 797:	learn: 0.0203163	total: 59.5s	remaining: 15.1s
# 798:	learn: 0.0202911	total: 59.6s	remaining: 15s
# 799:	learn: 0.0202379	total: 59.7s	remaining: 14.9s
# 800:	learn: 0.0201600	total: 59.7s	remaining: 14.8s
# 801:	learn: 0.0201354	total: 59.8s	remaining: 14.8s
# 802:	learn: 0.0201004	total: 59.8s	remaining: 14.7s
# 803:	learn: 0.0200556	total: 59.9s	remaining: 14.6s
# 804:	learn: 0.0200020	total: 59.9s	remaining: 14.5s
# 805:	learn: 0.0199639	total: 1m	remaining: 14.4s
# 806:	learn: 0.0199462	total: 1m	remaining: 14.4s
# 807:	learn: 0.0199007	total: 1m	remaining: 14.3s
# 808:	learn: 0.0198809	total: 1m	remaining: 14.2s
# 809:	learn: 0.0198390	total: 1m	remaining: 14.1s
# 810:	learn: 0.0198130	total: 1m	remaining: 14.1s
# 811:	learn: 0.0197790	total: 1m	remaining: 14s
# 812:	learn: 0.0197467	total: 1m	remaining: 13.9s
# 813:	learn: 0.0197010	total: 1m	remaining: 13.8s
# 814:	learn: 0.0196669	total: 1m	remaining: 13.7s
# 815:	learn: 0.0196511	total: 1m	remaining: 13.7s
# 816:	learn: 0.0196106	total: 1m	remaining: 13.6s
# 817:	learn: 0.0195813	total: 1m	remaining: 13.5s
# 818:	learn: 0.0195655	total: 1m	remaining: 13.4s
# 819:	learn: 0.0195122	total: 1m	remaining: 13.4s
# 820:	learn: 0.0194932	total: 1m	remaining: 13.3s
# 821:	learn: 0.0194540	total: 1m 1s	remaining: 13.2s
# 822:	learn: 0.0194322	total: 1m 1s	remaining: 13.1s
# 823:	learn: 0.0193979	total: 1m 1s	remaining: 13.1s
# 824:	learn: 0.0193761	total: 1m 1s	remaining: 13s
# 825:	learn: 0.0193486	total: 1m 1s	remaining: 12.9s
# 826:	learn: 0.0193291	total: 1m 1s	remaining: 12.8s
# 827:	learn: 0.0193027	total: 1m 1s	remaining: 12.8s
# 828:	learn: 0.0192751	total: 1m 1s	remaining: 12.7s
# 829:	learn: 0.0192564	total: 1m 1s	remaining: 12.6s
# 830:	learn: 0.0192301	total: 1m 1s	remaining: 12.5s
# 831:	learn: 0.0191903	total: 1m 1s	remaining: 12.5s
# 832:	learn: 0.0191329	total: 1m 1s	remaining: 12.4s
# 833:	learn: 0.0191154	total: 1m 1s	remaining: 12.3s
# 834:	learn: 0.0190794	total: 1m 1s	remaining: 12.2s
# 835:	learn: 0.0190628	total: 1m 1s	remaining: 12.2s
# 836:	learn: 0.0190328	total: 1m 2s	remaining: 12.1s
# 837:	learn: 0.0189948	total: 1m 2s	remaining: 12s
# 838:	learn: 0.0189836	total: 1m 2s	remaining: 11.9s
# 839:	learn: 0.0189629	total: 1m 2s	remaining: 11.8s
# 840:	learn: 0.0189465	total: 1m 2s	remaining: 11.8s
# 841:	learn: 0.0189288	total: 1m 2s	remaining: 11.7s
# 842:	learn: 0.0188971	total: 1m 2s	remaining: 11.6s
# 843:	learn: 0.0188616	total: 1m 2s	remaining: 11.5s
# 844:	learn: 0.0188141	total: 1m 2s	remaining: 11.5s
# 845:	learn: 0.0187821	total: 1m 2s	remaining: 11.4s
# 846:	learn: 0.0187403	total: 1m 2s	remaining: 11.3s
# 847:	learn: 0.0187140	total: 1m 2s	remaining: 11.2s
# 848:	learn: 0.0186700	total: 1m 2s	remaining: 11.2s
# 849:	learn: 0.0186603	total: 1m 2s	remaining: 11.1s
# 850:	learn: 0.0186444	total: 1m 2s	remaining: 11s
# 851:	learn: 0.0186203	total: 1m 2s	remaining: 10.9s
# 852:	learn: 0.0186068	total: 1m 2s	remaining: 10.9s
# 853:	learn: 0.0185834	total: 1m 3s	remaining: 10.8s
# 854:	learn: 0.0185609	total: 1m 3s	remaining: 10.7s
# 855:	learn: 0.0185158	total: 1m 3s	remaining: 10.6s
# 856:	learn: 0.0184613	total: 1m 3s	remaining: 10.6s
# 857:	learn: 0.0184397	total: 1m 3s	remaining: 10.5s
# 858:	learn: 0.0184305	total: 1m 3s	remaining: 10.4s
# 859:	learn: 0.0183808	total: 1m 3s	remaining: 10.3s
# 860:	learn: 0.0183624	total: 1m 3s	remaining: 10.3s
# 861:	learn: 0.0183297	total: 1m 3s	remaining: 10.2s
# 862:	learn: 0.0182984	total: 1m 3s	remaining: 10.1s
# 863:	learn: 0.0182826	total: 1m 3s	remaining: 10s
# 864:	learn: 0.0182551	total: 1m 3s	remaining: 9.95s
# 865:	learn: 0.0182252	total: 1m 3s	remaining: 9.87s
# 866:	learn: 0.0182086	total: 1m 3s	remaining: 9.8s
# 867:	learn: 0.0181882	total: 1m 3s	remaining: 9.73s
# 868:	learn: 0.0181433	total: 1m 4s	remaining: 9.65s
# 869:	learn: 0.0180945	total: 1m 4s	remaining: 9.58s
# 870:	learn: 0.0180709	total: 1m 4s	remaining: 9.5s
# 871:	learn: 0.0180426	total: 1m 4s	remaining: 9.43s
# 872:	learn: 0.0180232	total: 1m 4s	remaining: 9.35s
# 873:	learn: 0.0179937	total: 1m 4s	remaining: 9.28s
# 874:	learn: 0.0179658	total: 1m 4s	remaining: 9.2s
# 875:	learn: 0.0179438	total: 1m 4s	remaining: 9.13s
# 876:	learn: 0.0179346	total: 1m 4s	remaining: 9.05s
# 877:	learn: 0.0179053	total: 1m 4s	remaining: 8.98s
# 878:	learn: 0.0178807	total: 1m 4s	remaining: 8.9s
# 879:	learn: 0.0178527	total: 1m 4s	remaining: 8.83s
# 880:	learn: 0.0178169	total: 1m 4s	remaining: 8.75s
# 881:	learn: 0.0177689	total: 1m 4s	remaining: 8.68s
# 882:	learn: 0.0177173	total: 1m 4s	remaining: 8.6s
# 883:	learn: 0.0176843	total: 1m 4s	remaining: 8.53s
# 884:	learn: 0.0176561	total: 1m 5s	remaining: 8.45s
# 885:	learn: 0.0176470	total: 1m 5s	remaining: 8.38s
# 886:	learn: 0.0176080	total: 1m 5s	remaining: 8.3s
# 887:	learn: 0.0175954	total: 1m 5s	remaining: 8.23s
# 888:	learn: 0.0175642	total: 1m 5s	remaining: 8.15s
# 889:	learn: 0.0175414	total: 1m 5s	remaining: 8.08s
# 890:	learn: 0.0175204	total: 1m 5s	remaining: 8s
# 891:	learn: 0.0174905	total: 1m 5s	remaining: 7.93s
# 892:	learn: 0.0174741	total: 1m 5s	remaining: 7.85s
# 893:	learn: 0.0174514	total: 1m 5s	remaining: 7.78s
# 894:	learn: 0.0174409	total: 1m 5s	remaining: 7.7s
# 895:	learn: 0.0173885	total: 1m 5s	remaining: 7.62s
# 896:	learn: 0.0173687	total: 1m 5s	remaining: 7.55s
# 897:	learn: 0.0173334	total: 1m 5s	remaining: 7.48s
# 898:	learn: 0.0173151	total: 1m 5s	remaining: 7.4s
# 899:	learn: 0.0172824	total: 1m 5s	remaining: 7.33s
# 900:	learn: 0.0172481	total: 1m 6s	remaining: 7.25s
# 901:	learn: 0.0171860	total: 1m 6s	remaining: 7.18s
# 902:	learn: 0.0171451	total: 1m 6s	remaining: 7.1s
# 903:	learn: 0.0171046	total: 1m 6s	remaining: 7.03s
# 904:	learn: 0.0170678	total: 1m 6s	remaining: 6.95s
# 905:	learn: 0.0170460	total: 1m 6s	remaining: 6.88s
# 906:	learn: 0.0170092	total: 1m 6s	remaining: 6.81s
# 907:	learn: 0.0169566	total: 1m 6s	remaining: 6.73s
# 908:	learn: 0.0169298	total: 1m 6s	remaining: 6.66s
# 909:	learn: 0.0168980	total: 1m 6s	remaining: 6.59s
# 910:	learn: 0.0168641	total: 1m 6s	remaining: 6.51s
# 911:	learn: 0.0168551	total: 1m 6s	remaining: 6.44s
# 912:	learn: 0.0168021	total: 1m 6s	remaining: 6.37s
# 913:	learn: 0.0167888	total: 1m 6s	remaining: 6.3s
# 914:	learn: 0.0167519	total: 1m 6s	remaining: 6.22s
# 915:	learn: 0.0167234	total: 1m 7s	remaining: 6.15s
# 916:	learn: 0.0166903	total: 1m 7s	remaining: 6.08s
# 917:	learn: 0.0166515	total: 1m 7s	remaining: 6s
# 918:	learn: 0.0166113	total: 1m 7s	remaining: 5.93s
# 919:	learn: 0.0165792	total: 1m 7s	remaining: 5.86s
# 920:	learn: 0.0165662	total: 1m 7s	remaining: 5.78s
# 921:	learn: 0.0165414	total: 1m 7s	remaining: 5.71s
# 922:	learn: 0.0165228	total: 1m 7s	remaining: 5.63s
# 923:	learn: 0.0164947	total: 1m 7s	remaining: 5.56s
# 924:	learn: 0.0164735	total: 1m 7s	remaining: 5.49s
# 925:	learn: 0.0164563	total: 1m 7s	remaining: 5.41s
# ...
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=11, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=12, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=13, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=14, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=15, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=16, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=17, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=18, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=19, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=20, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=21, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=22, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=23, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=24, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=25, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=26, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=27, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=28, ...)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=29, ...)
# LGBMClassifier(random_state=5)
# LGBMClassifier(random_state=6)
# LGBMClassifier(random_state=7)
# LGBMClassifier(random_state=8)
# LGBMClassifier(random_state=9)
# LGBMClassifier(random_state=10)
# LGBMClassifier(random_state=11)
# LGBMClassifier(random_state=12)
# LGBMClassifier(random_state=13)
# LGBMClassifier(random_state=14)
# LGBMClassifier(random_state=15)
# LGBMClassifier(random_state=16)
# LGBMClassifier(random_state=17)
# LGBMClassifier(random_state=18)
# LGBMClassifier(random_state=19)
# LGBMClassifier(random_state=20)
# LGBMClassifier(random_state=21)
# LGBMClassifier(random_state=22)
# LGBMClassifier(random_state=23)
# LGBMClassifier(random_state=24)
# LGBMClassifier(random_state=25)
# LGBMClassifier(random_state=26)
# LGBMClassifier(random_state=27)
# LGBMClassifier(random_state=28)
# LGBMClassifier(random_state=29)
# ExtraTreesClassifier(random_state=5)
# ExtraTreesClassifier(random_state=6)
# ExtraTreesClassifier(random_state=7)
# ExtraTreesClassifier(random_state=8)
# ExtraTreesClassifier(random_state=9)
# ExtraTreesClassifier(random_state=10)
# ExtraTreesClassifier(random_state=11)
# ExtraTreesClassifier(random_state=12)
# ExtraTreesClassifier(random_state=13)
# ExtraTreesClassifier(random_state=14)
# ExtraTreesClassifier(random_state=15)
# ExtraTreesClassifier(random_state=16)
# ExtraTreesClassifier(random_state=17)
# ExtraTreesClassifier(random_state=18)
# ExtraTreesClassifier(random_state=19)
# ExtraTreesClassifier(random_state=20)
# ExtraTreesClassifier(random_state=21)
# ExtraTreesClassifier(random_state=22)
# ExtraTreesClassifier(random_state=23)
# ExtraTreesClassifier(random_state=24)
# ExtraTreesClassifier(random_state=25)
# ExtraTreesClassifier(random_state=26)
# ExtraTreesClassifier(random_state=27)
# ExtraTreesClassifier(random_state=28)
# ExtraTreesClassifier(random_state=29)
